# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime

# %%
pp = pd.read_csv('Data/precipitation.txt', skiprows=28)
pp.head()
# Out:
#   agency_cd\tsite_no\tdatetime\t20300_00045_00006\t20300_00045_00006_cd
# 0                             5s\t15s\t20d\t14n\t10s
# 1         USGS\t393938104572101\t2009-05-05\t0.00\tA
# 2         USGS\t393938104572101\t2009-05-06\t0.00\tA
# 3         USGS\t393938104572101\t2009-05-07\t0.00\tA
# 4         USGS\t393938104572101\t2009-05-08\t0.01\tA

# %%
pp = pd.read_csv('Data/precipitation.txt', skiprows=28, delimiter='\t')
pp.head()
# Out:
#   agency_cd          site_no    datetime 20300_00045_00006  \
# 0        5s              15s         20d               14n
# 1      USGS  393938104572101  2009-05-05              0.00
# 2      USGS  393938104572101  2009-05-06              0.00
# 3      USGS  393938104572101  2009-05-07              0.00
# 4      USGS  393938104572101  2009-05-08              0.01
#
#   20300_00045_00006_cd
# 0                  10s
# 1                    A
# 2                    A
# 3                    A
# 4                    A

# %%
pp = pp.iloc[1:]
pp.head()
# Out:
#   agency_cd          site_no    datetime 20300_00045_00006  \
# 1      USGS  393938104572101  2009-05-05              0.00
# 2      USGS  393938104572101  2009-05-06              0.00
# 3      USGS  393938104572101  2009-05-07              0.00
# 4      USGS  393938104572101  2009-05-08              0.01
# 5      USGS  393938104572101  2009-05-09              0.08
#
#   20300_00045_00006_cd
# 1                    A
# 2                    A
# 3                    A
# 4                    A
# 5                    A

# %%
pp.columns = ['Agency','SiteNumber','datetime','pp','code']
pp.head()
# Out:
#   Agency       SiteNumber    datetime    pp code
# 1   USGS  393938104572101  2009-05-05  0.00    A
# 2   USGS  393938104572101  2009-05-06  0.00    A
# 3   USGS  393938104572101  2009-05-07  0.00    A
# 4   USGS  393938104572101  2009-05-08  0.01    A
# 5   USGS  393938104572101  2009-05-09  0.08    A

# %%
pp = pp.rename(columns = {'datetime':'Datetime', 'pp':'Precipitation_in',
                         'code':'Code'})
pp
# Out:
#      Agency       SiteNumber    Datetime Precipitation_in Code
# 1      USGS  393938104572101  2009-05-05             0.00    A
# 2      USGS  393938104572101  2009-05-06             0.00    A
# 3      USGS  393938104572101  2009-05-07             0.00    A
# 4      USGS  393938104572101  2009-05-08             0.01    A
# 5      USGS  393938104572101  2009-05-09             0.08    A
# ...     ...              ...         ...              ...  ...
# 4171   USGS  393938104572101  2020-10-04              NaN  NaN
# 4172   USGS  393938104572101  2020-10-05              NaN  NaN
# 4173   USGS  393938104572101  2020-10-06              NaN  NaN
# 4174   USGS  393938104572101  2020-10-07              Ssn    P
# 4175   USGS  393938104572101  2020-10-08              Ssn    P
#
# [4175 rows x 5 columns]

# %%
pp.reset_index(drop = True)
pp.head()
# Out:
#   Agency       SiteNumber    Datetime Precipitation_in Code
# 1   USGS  393938104572101  2009-05-05             0.00    A
# 2   USGS  393938104572101  2009-05-06             0.00    A
# 3   USGS  393938104572101  2009-05-07             0.00    A
# 4   USGS  393938104572101  2009-05-08             0.01    A
# 5   USGS  393938104572101  2009-05-09             0.08    A

# %%
pp.tail()
# Out:
#      Agency       SiteNumber    Datetime Precipitation_in Code
# 4171   USGS  393938104572101  2020-10-04              NaN  NaN
# 4172   USGS  393938104572101  2020-10-05              NaN  NaN
# 4173   USGS  393938104572101  2020-10-06              NaN  NaN
# 4174   USGS  393938104572101  2020-10-07              Ssn    P
# 4175   USGS  393938104572101  2020-10-08              Ssn    P

# %%
pp.head()
# Out:
#   Agency       SiteNumber    Datetime Precipitation_in Code
# 1   USGS  393938104572101  2009-05-05             0.00    A
# 2   USGS  393938104572101  2009-05-06             0.00    A
# 3   USGS  393938104572101  2009-05-07             0.00    A
# 4   USGS  393938104572101  2009-05-08             0.01    A
# 5   USGS  393938104572101  2009-05-09             0.08    A

# %%
pd.to_numeric(pp['Precipitation_in'], errors='coerce').notnull()
# Out:
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
#         ...
# 4171    False
# 4172    False
# 4173    False
# 4174    False
# 4175    False
# Name: Precipitation_in, Length: 4175, dtype: bool

# %%
pp_filtered = pp[pd.to_numeric(pp['Precipitation_in'], errors='coerce').notnull()]
pp_filtered
# Out:
#      Agency       SiteNumber    Datetime Precipitation_in Code
# 1      USGS  393938104572101  2009-05-05             0.00    A
# 2      USGS  393938104572101  2009-05-06             0.00    A
# 3      USGS  393938104572101  2009-05-07             0.00    A
# 4      USGS  393938104572101  2009-05-08             0.01    A
# 5      USGS  393938104572101  2009-05-09             0.08    A
# ...     ...              ...         ...              ...  ...
# 4163   USGS  393938104572101  2020-09-26             0.00    P
# 4164   USGS  393938104572101  2020-09-27             0.00    P
# 4165   USGS  393938104572101  2020-09-28             0.00    P
# 4166   USGS  393938104572101  2020-09-29             0.00    P
# 4167   USGS  393938104572101  2020-09-30             0.00    P
#
# [1941 rows x 5 columns]

# %%
pp_filtered.describe()
# Out:
#        Agency       SiteNumber    Datetime Precipitation_in  Code
# count    1941             1941        1941             1941  1941
# unique      1                1        1941               81     2
# top      USGS  393938104572101  2014-04-10             0.00     A
# freq     1941             1941           1             1408  1762

# %%
pp_filtered.dtypes
# Out:
# Agency              object
# SiteNumber          object
# Datetime            object
# Precipitation_in    object
# Code                object
# dtype: object

# %%
pp_filtered['Precipitation_in'] = pd.to_numeric(pp_filtered['Precipitation_in'])
pp_filtered.dtypes
# Out:
# <ipython-input-17-ae38effddca1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pp_filtered['Precipitation_in'] = pd.to_numeric(pp_filtered['Precipitation_in'])
# Agency               object
# SiteNumber           object
# Datetime             object
# Precipitation_in    float64
# Code                 object
# dtype: object

# %%
pp_filtered['Precipitation_in'].plot()
# Out:
# <AxesSubplot:>

# %%
pp_filtered['Datetime'].dtype
# Out:
# dtype('O')

# %%
pp_filtered['Datetime'] = pd.to_datetime(pp_filtered['Datetime'])
pp_filtered.dtypes
# Out:
# <ipython-input-20-ed31edac0a38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pp_filtered['Datetime'] = pd.to_datetime(pp_filtered['Datetime'])
# Agency                      object
# SiteNumber                  object
# Datetime            datetime64[ns]
# Precipitation_in           float64
# Code                        object
# dtype: object

# %%
pp_filtered
# Out:
#      Agency       SiteNumber   Datetime  Precipitation_in Code
# 1      USGS  393938104572101 2009-05-05              0.00    A
# 2      USGS  393938104572101 2009-05-06              0.00    A
# 3      USGS  393938104572101 2009-05-07              0.00    A
# 4      USGS  393938104572101 2009-05-08              0.01    A
# 5      USGS  393938104572101 2009-05-09              0.08    A
# ...     ...              ...        ...               ...  ...
# 4163   USGS  393938104572101 2020-09-26              0.00    P
# 4164   USGS  393938104572101 2020-09-27              0.00    P
# 4165   USGS  393938104572101 2020-09-28              0.00    P
# 4166   USGS  393938104572101 2020-09-29              0.00    P
# 4167   USGS  393938104572101 2020-09-30              0.00    P
#
# [1941 rows x 5 columns]

# %%
pp_filtered = pp_filtered.set_index('Datetime')
pp_filtered.head()
# Out:
#            Agency       SiteNumber  Precipitation_in Code
# Datetime
# 2009-05-05   USGS  393938104572101              0.00    A
# 2009-05-06   USGS  393938104572101              0.00    A
# 2009-05-07   USGS  393938104572101              0.00    A
# 2009-05-08   USGS  393938104572101              0.01    A
# 2009-05-09   USGS  393938104572101              0.08    A

# %%
pp_filtered['Precipitation_in'].plot(kind='area')
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
pp_filtered.iloc[:50]['Precipitation_in'].plot(kind='area')
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
pp_filtered['Precipitation_in'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pp_filtered[pp_filtered['Precipitation_in']>0].boxplot()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
ax.scatter(pp_filtered.index, pp_filtered['Precipitation_in'].values, label ='Pp')
ax.set_xlabel('Date')
ax.set_ylabel('Prcipitation(in)')
ax.legend(loc='upper left')
plt.show()

# %%
pp_filtered.index.max()
# Out:
# Timestamp('2020-09-30 00:00:00')

# %%
pp_filtered.index.min()
# Out:
# Timestamp('2009-05-05 00:00:00')

# %%
pp_filtered.index.max() - pp_filtered.index.min()
# Out:
# Timedelta('4166 days 00:00:00')

# %%
pp_filtered['Precipitation_in'].loc['2019-07-01':'2020-06-30'].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
pp.head()
# Out:
#   Agency       SiteNumber    Datetime Precipitation_in Code
# 1   USGS  393938104572101  2009-05-05             0.00    A
# 2   USGS  393938104572101  2009-05-06             0.00    A
# 3   USGS  393938104572101  2009-05-07             0.00    A
# 4   USGS  393938104572101  2009-05-08             0.01    A
# 5   USGS  393938104572101  2009-05-09             0.08    A

# %%
pp['Datetime']=pd.to_datetime(pp['Datetime'])
pp.dtypes
# Out:
# Agency                      object
# SiteNumber                  object
# Datetime            datetime64[ns]
# Precipitation_in            object
# Code                        object
# dtype: object

# %%
pp_ordered = pp.set_index('Datetime')
pp_ordered
# Out:
#            Agency       SiteNumber Precipitation_in Code
# Datetime
# 2009-05-05   USGS  393938104572101             0.00    A
# 2009-05-06   USGS  393938104572101             0.00    A
# 2009-05-07   USGS  393938104572101             0.00    A
# 2009-05-08   USGS  393938104572101             0.01    A
# 2009-05-09   USGS  393938104572101             0.08    A
# ...           ...              ...              ...  ...
# 2020-10-04   USGS  393938104572101              NaN  NaN
# 2020-10-05   USGS  393938104572101              NaN  NaN
# 2020-10-06   USGS  393938104572101              NaN  NaN
# 2020-10-07   USGS  393938104572101              Ssn    P
# 2020-10-08   USGS  393938104572101              Ssn    P
#
# [4175 rows x 4 columns]

# %%
pp_ordered['Precipitation_in'] = pd.to_numeric(pp_ordered['Precipitation_in'],
                                              errors='coerce')
pp_ordered.head()
# Out:
#            Agency       SiteNumber  Precipitation_in Code
# Datetime
# 2009-05-05   USGS  393938104572101              0.00    A
# 2009-05-06   USGS  393938104572101              0.00    A
# 2009-05-07   USGS  393938104572101              0.00    A
# 2009-05-08   USGS  393938104572101              0.01    A
# 2009-05-09   USGS  393938104572101              0.08    A

# %%
pp_ordered.dtypes
# Out:
# Agency               object
# SiteNumber           object
# Precipitation_in    float64
# Code                 object
# dtype: object

# %%
pp_ordered['Precipitation_in'].count()
# Out:
# 1941

# %%
timeDelta = pp_ordered.index.max() - pp_ordered.index.min()

# %%
timeDelta.days - pp_ordered['Precipitation_in'].count()
# Out:
# 2233

# %%
pp_ordered['Precipitation_in'].isnull().sum()
# Out:
# 2234

# %%
pp_ordered['Day'] = pp_ordered.index.day
pp_ordered['Month'] = pp_ordered.index.month
pp_ordered['Year'] = pp_ordered.index.year
pp_ordered.head()
# Out:
#            Agency       SiteNumber  Precipitation_in Code  Day  Month  Year
# Datetime
# 2009-05-05   USGS  393938104572101              0.00    A    5      5  2009
# 2009-05-06   USGS  393938104572101              0.00    A    6      5  2009
# 2009-05-07   USGS  393938104572101              0.00    A    7      5  2009
# 2009-05-08   USGS  393938104572101              0.01    A    8      5  2009
# 2009-05-09   USGS  393938104572101              0.08    A    9      5  2009

# %%
pp_ordered.groupby('Year').count()
# Out:
#       Agency  SiteNumber  Precipitation_in  Code  Day  Month
# Year
# 2009     241         241               149   149  241    241
# 2010     365         365                 0     0  365    365
# 2011     365         365               187   187  365    365
# 2012     366         366               183   183  366    366
# 2013     365         365               183   183  365    365
# 2014     365         365               178   178  365    365
# 2015     365         365               177   177  365    365
# 2016     366         366               176   176  366    366
# 2017     365         365               170   170  365    365
# 2018     365         365               183   183  365    365
# 2019     365         365               176   176  365    365
# 2020     282         282               179   181  282    282

# %%
pp_ordered.groupby('Year').sum()
# Out:
#       Precipitation_in   Day  Month
# Year
# 2009              9.93  3865   2062
# 2010              0.00  5738   2382
# 2011             13.16  5738   2382
# 2012              7.50  5767   2384
# 2013             12.57  5738   2382
# 2014             10.79  5738   2382
# 2015             12.22  5738   2382
# 2016              5.17  5767   2384
# 2017              3.32  5738   2382
# 2018              6.66  5738   2382
# 2019              5.15  5738   2382
# 2020              3.22  4346   1452

# %%
pp_ordered.groupby('Year').mean()
# Out:
#       Precipitation_in        Day     Month
# Year
# 2009          0.066644  16.037344  8.556017
# 2010               NaN  15.720548  6.526027
# 2011          0.070374  15.720548  6.526027
# 2012          0.040984  15.756831  6.513661
# 2013          0.068689  15.720548  6.526027
# 2014          0.060618  15.720548  6.526027
# 2015          0.069040  15.720548  6.526027
# 2016          0.029375  15.756831  6.513661
# 2017          0.019529  15.720548  6.526027
# 2018          0.036393  15.720548  6.526027
# 2019          0.029261  15.720548  6.526027
# 2020          0.017989  15.411348  5.148936

# %%
pp_ordered.groupby('Year').describe()
# Out:
#      Precipitation_in                                                     Day  \
#                 count      mean       std  min  25%  50%     75%   max  count
# Year
# 2009            149.0  0.066644  0.160685  0.0  0.0  0.0  0.0400  1.08  241.0
# 2010              0.0       NaN       NaN  NaN  NaN  NaN     NaN   NaN  365.0
# 2011            187.0  0.070374  0.229170  0.0  0.0  0.0  0.0150  1.67  365.0
# 2012            183.0  0.040984  0.168239  0.0  0.0  0.0  0.0000  1.50  366.0
# 2013            183.0  0.068689  0.197341  0.0  0.0  0.0  0.0300  1.34  365.0
# 2014            178.0  0.060618  0.179088  0.0  0.0  0.0  0.0375  1.35  365.0
# 2015            177.0  0.069040  0.206818  0.0  0.0  0.0  0.0300  1.83  365.0
# 2016            176.0  0.029375  0.100280  0.0  0.0  0.0  0.0000  0.89  366.0
# 2017            170.0  0.019529  0.058823  0.0  0.0  0.0  0.0000  0.40  365.0
# 2018            183.0  0.036393  0.115507  0.0  0.0  0.0  0.0000  0.87  365.0
# 2019            176.0  0.029261  0.088156  0.0  0.0  0.0  0.0100  0.57  365.0
# 2020            179.0  0.017989  0.083049  0.0  0.0  0.0  0.0000  0.80  282.0
#
#                  ...              Month                                     \
#            mean  ...   75%   max  count      mean       std  min  25%  50%
# Year             ...
# 2009  16.037344  ...  24.0  31.0  241.0  8.556017  2.272566  5.0  7.0  9.0
# 2010  15.720548  ...  23.0  31.0  365.0  6.526027  3.452584  1.0  4.0  7.0
# 2011  15.720548  ...  23.0  31.0  365.0  6.526027  3.452584  1.0  4.0  7.0
# 2012  15.756831  ...  23.0  31.0  366.0  6.513661  3.455958  1.0  4.0  7.0
# 2013  15.720548  ...  23.0  31.0  365.0  6.526027  3.452584  1.0  4.0  7.0
# 2014  15.720548  ...  23.0  31.0  365.0  6.526027  3.452584  1.0  4.0  7.0
# 2015  15.720548  ...  23.0  31.0  365.0  6.526027  3.452584  1.0  4.0  7.0
# 2016  15.756831  ...  23.0  31.0  366.0  6.513661  3.455958  1.0  4.0  7.0
# 2017  15.720548  ...  23.0  31.0  365.0  6.526027  3.452584  1.0  4.0  7.0
# 2018  15.720548  ...  23.0  31.0  365.0  6.526027  3.452584  1.0  4.0  7.0
# 2019  15.720548  ...  23.0  31.0  365.0  6.526027  3.452584  1.0  4.0  7.0
# 2020  15.411348  ...  23.0  31.0  282.0  5.148936  2.679662  1.0  3.0  5.0
#
#
#         75%   max
# Year
# 2009  11.00  12.0
# 2010  10.00  12.0
# 2011  10.00  12.0
# 2012   9.75  12.0
# 2013  10.00  12.0
# 2014  10.00  12.0
# 2015  10.00  12.0
# 2016   9.75  12.0
# 2017  10.00  12.0
# 2018  10.00  12.0
# 2019  10.00  12.0
# 2020   7.00  10.0
#
# [12 rows x 24 columns]

# %%
pp_ordered.groupby(['Year','Month']).count()
# Out:
#             Agency  SiteNumber  Precipitation_in  Code  Day
# Year Month
# 2009 5          27          27                27    27   27
#      6          30          30                30    30   30
#      7          31          31                31    31   31
#      8          31          31                31    31   31
#      9          30          30                30    30   30
# ...            ...         ...               ...   ...  ...
# 2020 6          30          30                30    30   30
#      7          31          31                31    31   31
#      8          31          31                30    30   31
#      9          30          30                30    30   30
#      10          8           8                 0     2    8
#
# [138 rows x 5 columns]

# %%
pp_ordered[['Month','Precipitation_in']].loc['2019-1-1':'2019-12-31'].groupby('Month').sum()
# Out:
#        Precipitation_in
# Month
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.11
# 5                  1.41
# 6                  0.83
# 7                  1.35
# 8                  0.85
# 9                  0.60
# 10                 0.00
# 11                 0.00
# 12                 0.00

# %%
pp_ordered[['Month','Precipitation_in']].loc['2019-1-1':'2019-12-31'].groupby('Month').sum().plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
pp_ordered[['Month','Precipitation_in']].loc['2019-1-1':'2019-12-31'].groupby('Month').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
pp_ordered.to_csv('Data/outPpt.csv')
